# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
Nclass=500
X1= np.random.randn(Nclass, 2)+ np.array([0, -2])
X2= np.random.randn(Nclass, 2)+ np.array([2, 2])
X3= np.random.randn(Nclass, 2)+ np.array([-2, 2])
Y = np.array([0]*Nclass + [1]*Nclass + [2]*Nclass)

# %%
Y
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
Y.shape
# Out:
# (1500,)

# %%
X=np.vstack([X1, X2, X3])

# %%
X
# Out:
# array([[ 0.53507692, -1.34484966],
#        [-0.52254551, -2.11332821],
#        [-0.10532492, -2.56534079],
#        ...,
#        [-3.54425134,  0.88660023],
#        [-2.90728507,  1.1687404 ],
#        [-1.98879062,  2.91290784]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=Y, s=100, alpha=0.75)

# %%
D = 2
M = 3
K = 3

# %%
W1 = np.random.randn(D, M)
b1 = np.random.randn(M)
W2 = np.random.randn(M, K)
b2 = np.random.randn(K)

# %%
b1
# Out:
# array([-0.68732173, -0.10657983,  0.97991472])

# %%
def forward(X, W1, b1, W2, b2):
    Z = 1/(1+np.exp(-X.dot(W1)-b1))
    A = Z.dot(W2)+b2
    Y_pred = np.exp(A)/A.sum(axis=1).reshape(-1, 1)
    print (Y_pred)
    return Y_pred

# %%
def classication_rate(Y, P):
    n_total = 0
    n_correct = 0
    for i in range(0, len(Y)):
        n_total+=1
        if Y[i] == P[i]:
            n_correct+=1
    return n_correct/n_total

# %%
P_Y_all=forward(X, W1, b1, W2, b2)
P_Y=np.argmax(P_Y_all, axis=1)
rate=classication_rate(Y, P_Y)
print(rate)
# Out:
# [[ 1.41537855  0.17986602  3.01545224]
#  [ 1.51706552  0.3095573   5.08549315]
#  [ 1.47340049  0.27491801  4.68500137]
#  ...
#  [ 3.92497832  1.24673277 17.71690601]
#  [ 1.9844486   0.55426885  8.0177367 ]
#  [ 1.2483529   0.21349686  2.93860879]]
# 0.3333333333333333
